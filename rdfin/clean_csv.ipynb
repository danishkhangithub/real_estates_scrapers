# %%
import pandas as pd

# %%
df = pd.read_csv('redfin.csv', names = ['Name','Url', 'Address'])
df.drop_duplicates(subset = 'Name', keep = 'first', inplace = True)

# %%
df.to_csv('output.csv')

# %%
data= pd.read_csv('output.csv')

# %%
data
# Out:
#     Unnamed: 0                                               Name  \
# 0            0                3772 6th Ave, Los Angeles, CA 90018
# 1            2          3615 Kalsman Dr #3, Los Angeles, CA 90016
# 2            4          8221 Langdon Ave #210, Van Nuys, CA 91406
# 3            6      222 S Central Ave #239, Los Angeles, CA 90012
# 4            8       6145 Shoup Ave #46, Woodland Hills, CA 91367
# 5           10    1037 N Laurel Ave #18, West Hollywood, CA 90046
# 6           12    4060 Glencoe Ave #226, Marina Del Rey, CA 90292
# 7           14      11970 Montana Ave #206, Los Angeles, CA 90049
# 8           16            3872 Dwiggins St, Los Angeles, CA 90063
# 9           18             4831 Toland Way, Los Angeles, CA 90042
# 10          20    4411 Los Feliz Blvd #605, Los Angeles, CA 90027
# 11          22             3311 Waverly Dr, Los Angeles, CA 90027
# 12          24           305 Arnaz Dr #204, Los Angeles, CA 90048
# ...

# %%
data = data.drop('Unnamed: 0', axis = 1)
# Out:
#                                                  Name  \
# 0                 3772 6th Ave, Los Angeles, CA 90018
# 1           3615 Kalsman Dr #3, Los Angeles, CA 90016
# 2           8221 Langdon Ave #210, Van Nuys, CA 91406
# 3       222 S Central Ave #239, Los Angeles, CA 90012
# 4        6145 Shoup Ave #46, Woodland Hills, CA 91367
# 5     1037 N Laurel Ave #18, West Hollywood, CA 90046
# 6     4060 Glencoe Ave #226, Marina Del Rey, CA 90292
# 7       11970 Montana Ave #206, Los Angeles, CA 90049
# 8             3872 Dwiggins St, Los Angeles, CA 90063
# 9              4831 Toland Way, Los Angeles, CA 90042
# 10    4411 Los Feliz Blvd #605, Los Angeles, CA 90027
# 11             3311 Waverly Dr, Los Angeles, CA 90027
# 12           305 Arnaz Dr #204, Los Angeles, CA 90048
# 13             3736 Tuller Ave, Los Angeles, CA 90034
# 14  837 N West Knoll Dr #205, West Hollywood, CA 9...
# 15         1911 Manning Ave #2, Los Angeles, CA 90025
# ...
