# %%
import pandas as pd

# %%
import os
os.remove('funda.csv')

# %%
data = pd.read_csv('funda.csv')
data
# Out:
#                                             Name  \
# 0                   Keizersgracht 555, Amsterdam
# 1                     Herengracht 168, Amsterdam
# 2             Renswoudestraat 52 - 56, Amsterdam
# 3                          Hornweg 54, Amsterdam
# 4                    Cacaoweg 20 6a-f, Amsterdam
# 5                       Kraanspoor 50, Amsterdam
# 6   Willem Frederik Hermansstraat 167, Amsterdam
# 7                       Abberdaan 210, Amsterdam
# 8                       Abberdaan 212, Amsterdam
# 9                 Haarlemmerstraat 41, Amsterdam
# 10                    Leidsestraat 57, Amsterdam
# 11           Daniël Goedkoopstraat 27, Amsterdam
# 12                     Gyroscoopweg 6, Amsterdam
# 13             De Clercqstraat 125 BG, Amsterdam
# 14                Hemonystraat 54 -HS, Amsterdam
#
#                                         Price  \
# 0   vanaf € 676 /m²/jaar  incl. servicekosten
# 1   vanaf € 800 /m²/jaar  incl. servicekosten
# ...
